# %%
import seaborn as sns
color = sns.color_palette()
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
fmri = sns.load_dataset("fmri")

# %%
fmri.head(10)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# 5      s9         18  stim  parietal -0.103513
# 6      s8         18  stim  parietal -0.064408
# 7      s7         18  stim  parietal -0.060526
# 8      s6         18  stim  parietal -0.007029
# 9      s5         18  stim  parietal -0.040557

# %%
fmri['event'].value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
sns.lineplot(x = 'timepoint',y = 'signal',data = fmri,hue = 'event',style = 'event',markers = True)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.barplot(x = 'species',y = 'sepal_length', data = iris)
plt.show()

# %%
sns.barplot(x = 'species',y = 'sepal_length', data = iris,palette = 'Blues_d')
plt.show()

# %%
sns.set(style = 'whitegrid')
sns.barplot(x = 'species',y = 'sepal_length', data = iris,palette = 'rocket') # palette = Blues_d,rocket,vlag
plt.show()

# %%
sns.barplot(x = 'species',y = 'sepal_length', data = iris,color = 'orange')
plt.show()

# %%
sns.set(rc = {'figure.figsize' : (15,10)})
sns.barplot(x = 'species',y = 'sepal_length',data = iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.scatterplot(x = 'sepal_length',y = 'petal_length',data = iris,hue = 'species',style = 'species',s = 70 )
plt.show()

# %%
sns.scatterplot(x = 'sepal_length',y = 'petal_length',data = iris,hue = 'petal_length',style = 'species',s = 50 )
plt.legend(['setosa','veginica','versicolour'])
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dia = sns.load_dataset('diamonds')
dia.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
sns.distplot(dia['price'])
plt.show()

# %%
sns.distplot(dia['price'],color ='purple')
plt.show()

# %%
sns.distplot(dia['price'],hist = False,color ='green')
plt.show()

# %%
sns.distplot(dia['price'],kde = False)
plt.show()

# %%
sns.distplot(dia['price'],kde = False,bins =10,color = 'g')
plt.show()

# %%
sns.distplot(dia['price'],color = 'purple',kde = False,bins =10,vertical =True)
plt.show()

# %%
sns.jointplot(x = 'sepal_length',y = 'petal_length',data = iris)
plt.show()

# %%
sns.jointplot(x = 'sepal_length',y = 'petal_length',data = iris,color='brown')
plt.show()

# %%
sns.jointplot(x = 'sepal_length',y = 'petal_length',data = iris,color = 'olive',kind = 'reg')
plt.show()

# %%
import pandas as pd
file = pd.read_csv('Dataset/customer_churn.csv')
churn = pd.DataFrame(file)

# %%
churn.head(10)
# Out:
#               Names   Age  Total_Purchase  Account_Manager  Years  Num_Sites  \
# 0  Cameron Williams  42.0        11066.80                0   7.22        8.0
# 1     Kevin Mueller  41.0        11916.22                0   6.50       11.0
# 2       Eric Lozano  38.0        12884.75                0   6.67       12.0
# 3     Phillip White  42.0         8010.76                0   6.71       10.0
# 4    Cynthia Norton  37.0         9191.58                0   5.56        9.0
# 5  Jessica Williams  48.0        10356.02                0   5.12        8.0
# 6       Eric Butler  44.0        11331.58                1   5.23       11.0
# 7     Zachary Walsh  32.0         9885.12                1   6.92        9.0
# 8       Ashlee Carr  43.0        14062.60                1   5.46       11.0
# 9    Jennifer Lynch  40.0         8066.94                1   7.11       11.0
#
#           Onboard_date                                           Location  \
# ...

# %%
churn['Churn'].value_counts()
# Out:
# 0    750
# 1    150
# Name: Churn, dtype: int64

# %%
sns.boxplot(x= 'Churn',y = 'Years',data = churn)
plt.show()

# %%
sns.boxplot(x = 'species',y = 'sepal_length',data= iris,palette ='Set2',linewidth =3)
plt.show()

# %%
sns.boxplot(x = 'Churn',y = 'Years',data=churn,order = [1,0]) # can changer the order
# Out:
# <Axes: xlabel='Churn', ylabel='Years'>

# %%
sns.boxplot(x = 'Churn',y = 'Years',data=churn,hue = 'Num_Sites')
plt.show()

# %%
sns.pairplot(iris,hue ='species')
plt.show()

# %%
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.set(rc = {'figure.figsize' :(20,15)})
sns.lmplot(x = 'carat',y = 'price',data = dia)

# %%
#confusion matrix

cm = metrics.confusion_matrics(y_test,y_pred) # for machine learning
cm = tf.math.confusion_matrics(y_test,y_pred) # for deep learning

import seaborn as sns
sns.heatmap(cm,annot=True,fmt='d')

# %%
#confusion matrix

import seaborn as sns
plt.figure(figsize = (10,8))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('Truth')
